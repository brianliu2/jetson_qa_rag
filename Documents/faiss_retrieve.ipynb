# %%
import faiss
import pandas as pd
import numpy as np

# %%
emb_df = pd.read_csv("./embeddings/Mesys_UserManual_v1_0_1220.csv")
print(emb_df.shape)
# Out:
# (40, 5)

# %%
emb_df.sample()
# Out:
#     PageNumber           ImagePath  \
# 32          33  images/page_33.png
#
#                                              PageText Visual_Input_Processed  \
# 32  **TRANSCRIPTION OF THE TEXT:**\n\n23    HDMI_S...                      Y
#
#                                            Embeddings
# 32  [0.009090332314372063, 0.04225197061896324, -0...

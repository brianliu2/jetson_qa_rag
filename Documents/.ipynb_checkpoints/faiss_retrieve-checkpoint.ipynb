# %%
import faiss
import pandas as pd
import numpy as np

# %%
emb_df = pd.read_csv("./embeddings/Mesys_UserManual_v1_0_1220.csv")
print(emb_df.shape)
# Out:
# (40, 5)

# %%
emb_df.sample()
# Out:
#     PageNumber           ImagePath  \
# 11          12  images/page_12.png
#
#                                              PageText Visual_Input_Processed  \
# 11  **TRANSCRIPTION OF THE TEXT:**\n\n10. PS——QSPI...                      Y
#
#                                            Embeddings
# 11  [0.019330790266394615, 0.050436828285455704, -...
